# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
indep=dataset[['age','bmi','children','sex_male','smoker_yes']]
dep=dataset['charges']

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV 
param_grid={'criterion':['squared_error','sbsolute_error','friedman_mse','poisson'],'max_features': ['auto','sqrt','log2'],'n_estimators':[10,100]}

# %%
grid=GridSearchCV(RandomForestRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(indep,dep)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Users\Thenm\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 60 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 13 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Thenm\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Thenm\anaconda3\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "C:\Users\Thenm\anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\Thenm\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 17 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Thenm\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Thenm\anaconda3\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "C:\Users\Thenm\anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\Thenm\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 26 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Thenm\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Thenm\anaconda3\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "C:\Users\Thenm\anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\Thenm\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'squared_error', 'friedman_mse', 'poisson', 'absolute_error'}. Got 'sbsolute_error' instead.
#
# --------------------------------------------------------------------------------
# 4 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Thenm\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Thenm\anaconda3\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "C:\Users\Thenm\anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\Thenm\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'poisson', 'absolute_error', 'friedman_mse', 'squared_error'}. Got 'sbsolute_error' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Thenm\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1102: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.81826584 0.83234209 0.81895777 0.83428793
#         nan        nan        nan        nan        nan        nan
#         nan        nan 0.81452094 0.83280849 0.82187916 0.83158877
#         nan        nan 0.81880372 0.83385826 0.81675472 0.83417187]
#   warnings.warn(
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'sbsolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
re=grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'criterion': 'squared_error', 'max_features': 'log2', 'n_estimators': 100}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.001281      0.001056         0.000000        0.000000
# 1        0.001391      0.001091         0.000000        0.000000
# 2        0.035892      0.003112         0.004916        0.001052
# 3        0.341473      0.026980         0.012357        0.001013
# 4        0.033606      0.002809         0.003482        0.001150
# 5        0.297652      0.013193         0.012449        0.001296
# 6        0.000711      0.000403         0.000000        0.000000
# 7        0.001247      0.000856         0.000000        0.000000
# 8        0.001114      0.000929         0.000000        0.000000
# 9        0.001568      0.000876         0.000000        0.000000
# 10       0.001230      0.000822         0.000000        0.000000
# 11       0.000910      0.000921         0.000000        0.000000
# 12       0.001310      0.000877         0.000000        0.000000
# 13       0.001051      0.000930         0.000000        0.000000
# 14       0.033266      0.002318         0.003119        0.000380
# 15       0.298914      0.011268         0.016203        0.010105
# 16       0.041164      0.010885         0.004819        0.001439
# 17       0.301812      0.008870         0.013407        0.003239
# 18       0.000505      0.000782         0.000000        0.000000
# 19       0.001506      0.000778         0.000000        0.000000
# 20       0.048510      0.002875         0.003871        0.000210
# 21       0.439088      0.108748         0.013158        0.003012
# 22       0.070187      0.021887         0.005134        0.002340
# 23       0.513178      0.178199         0.015531        0.004467
#
#    param_criterion param_max_features  param_n_estimators  \
# 0    squared_error               auto                  10
# 1    squared_error               auto                 100
# 2    squared_error               sqrt                  10
# 3    squared_error               sqrt                 100
# 4    squared_error               log2                  10
# 5    squared_error               log2                 100
# 6   sbsolute_error               auto                  10
# 7   sbsolute_error               auto                 100
# 8   sbsolute_error               sqrt                  10
# 9   sbsolute_error               sqrt                 100
# 10  sbsolute_error               log2                  10
# 11  sbsolute_error               log2                 100
# 12    friedman_mse               auto                  10
# 13    friedman_mse               auto                 100
# 14    friedman_mse               sqrt                  10
# 15    friedman_mse               sqrt                 100
# 16    friedman_mse               log2                  10
# 17    friedman_mse               log2                 100
# 18         poisson               auto                  10
# 19         poisson               auto                 100
# 20         poisson               sqrt                  10
# 21         poisson               sqrt                 100
# 22         poisson               log2                  10
# 23         poisson               log2                 100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...                NaN
# 1   {'criterion': 'squared_error', 'max_features':...                NaN
# 2   {'criterion': 'squared_error', 'max_features':...           0.839572
# 3   {'criterion': 'squared_error', 'max_features':...           0.853347
# 4   {'criterion': 'squared_error', 'max_features':...           0.840817
# 5   {'criterion': 'squared_error', 'max_features':...           0.861691
# 6   {'criterion': 'sbsolute_error', 'max_features'...                NaN
# 7   {'criterion': 'sbsolute_error', 'max_features'...                NaN
# 8   {'criterion': 'sbsolute_error', 'max_features'...                NaN
# 9   {'criterion': 'sbsolute_error', 'max_features'...                NaN
# 10  {'criterion': 'sbsolute_error', 'max_features'...                NaN
# 11  {'criterion': 'sbsolute_error', 'max_features'...                NaN
# 12  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 13  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.838809
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.853985
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.851459
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.859026
# 18  {'criterion': 'poisson', 'max_features': 'auto...                NaN
# 19  {'criterion': 'poisson', 'max_features': 'auto...                NaN
# 20  {'criterion': 'poisson', 'max_features': 'sqrt...           0.834702
# 21  {'criterion': 'poisson', 'max_features': 'sqrt...           0.859725
# 22  {'criterion': 'poisson', 'max_features': 'log2...           0.836671
# 23  {'criterion': 'poisson', 'max_features': 'log2...           0.859108
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2            0.763055           0.846709           0.821894
# 3            0.775318           0.857436           0.831834
# 4            0.757684           0.857890           0.828632
# 5            0.779721           0.859308           0.830009
# 6                 NaN                NaN                NaN
# 7                 NaN                NaN                NaN
# 8                 NaN                NaN                NaN
# 9                 NaN                NaN                NaN
# 10                NaN                NaN                NaN
# 11                NaN                NaN                NaN
# 12                NaN                NaN                NaN
# 13                NaN                NaN                NaN
# 14           0.749404           0.836863           0.804116
# 15           0.780667           0.857607           0.828218
# 16           0.759123           0.855174           0.817610
# 17           0.776889           0.853582           0.830414
# 18                NaN                NaN                NaN
# 19                NaN                NaN                NaN
# 20           0.765111           0.850050           0.813252
# 21           0.777105           0.863733           0.829219
# 22           0.758520           0.839806           0.822393
# 23           0.781626           0.859479           0.830049
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN               13
# 1                 NaN              NaN             NaN               13
# 2            0.820099         0.818266        0.029420               10
# 3            0.843775         0.832342        0.029845                5
# 4            0.809766         0.818958        0.034427                8
# 5            0.840711         0.834288        0.029712                1
# 6                 NaN              NaN             NaN               13
# 7                 NaN              NaN             NaN               13
# 8                 NaN              NaN             NaN               13
# 9                 NaN              NaN             NaN               13
# 10                NaN              NaN             NaN               13
# 11                NaN              NaN             NaN               13
# 12                NaN              NaN             NaN               13
# 13                NaN              NaN             NaN               13
# 14           0.843412         0.814521        0.035418               12
# 15           0.843564         0.832808        0.027996                4
# 16           0.826030         0.821879        0.034518                7
# 17           0.838032         0.831589        0.029228                6
# 18                NaN              NaN             NaN               13
# 19                NaN              NaN             NaN               13
# 20           0.830904         0.818804        0.029289                9
# 21           0.839509         0.833858        0.031100                3
# 22           0.826384         0.816755        0.029812               11
# 23           0.840597         0.834172        0.028571                2

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_Yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 49
# BMI: 12
# Children: 2
# Sex Male 0 or 1: 1
# Smoker Yes 0 or 1: 1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_Yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[22367.975579]
# C:\Users\Thenm\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
