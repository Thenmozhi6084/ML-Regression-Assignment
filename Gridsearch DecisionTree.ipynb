# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
indep=dataset[['age','bmi','children','sex_male','smoker_yes']]
dep=dataset['charges']

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid={'criterion':['squared_error','friedman_mse','absolute_error','poisson'],'max_features': ['sqrt','log2'],'splitter':['best','random']}

# %%
grid = GridSearchCV(DecisionTreeRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(indep,dep)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
re=grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'criterion': 'poisson', 'max_features': 'sqrt', 'splitter': 'best'}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.017003      0.003953         0.006242        0.002867
# 1        0.014911      0.002976         0.011676        0.003179
# 2        0.014224      0.001494         0.007181        0.002010
# 3        0.011028      0.001689         0.006812        0.002247
# 4        0.014302      0.002490         0.005413        0.001775
# 5        0.011093      0.003961         0.005781        0.002576
# 6        0.014055      0.002239         0.005750        0.002251
# 7        0.009758      0.001748         0.005589        0.000983
# 8        0.034704      0.003760         0.003035        0.000808
# 9        0.029187      0.002591         0.004903        0.001158
# 10       0.036068      0.008930         0.003829        0.001190
# 11       0.030672      0.005961         0.004912        0.001726
# 12       0.017339      0.001916         0.004753        0.001204
# 13       0.015995      0.001819         0.005016        0.000806
# 14       0.018253      0.004009         0.006142        0.001524
# 15       0.016813      0.002787         0.004699        0.001287
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4     friedman_mse               sqrt           best
# 5     friedman_mse               sqrt         random
# 6     friedman_mse               log2           best
# 7     friedman_mse               log2         random
# 8   absolute_error               sqrt           best
# 9   absolute_error               sqrt         random
# 10  absolute_error               log2           best
# 11  absolute_error               log2         random
# 12         poisson               sqrt           best
# 13         poisson               sqrt         random
# 14         poisson               log2           best
# 15         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.754662
# 1   {'criterion': 'squared_error', 'max_features':...           0.706156
# 2   {'criterion': 'squared_error', 'max_features':...           0.639702
# 3   {'criterion': 'squared_error', 'max_features':...           0.609802
# 4   {'criterion': 'friedman_mse', 'max_features': ...           0.713107
# 5   {'criterion': 'friedman_mse', 'max_features': ...           0.659533
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.705431
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.698520
# 8   {'criterion': 'absolute_error', 'max_features'...           0.747108
# 9   {'criterion': 'absolute_error', 'max_features'...           0.686674
# 10  {'criterion': 'absolute_error', 'max_features'...           0.672747
# 11  {'criterion': 'absolute_error', 'max_features'...           0.755876
# 12  {'criterion': 'poisson', 'max_features': 'sqrt...           0.745706
# 13  {'criterion': 'poisson', 'max_features': 'sqrt...           0.591274
# 14  {'criterion': 'poisson', 'max_features': 'log2...           0.637490
# 15  {'criterion': 'poisson', 'max_features': 'log2...           0.695518
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.627977           0.710848           0.708988
# 1            0.566809           0.666392           0.691224
# 2            0.657194           0.748434           0.622181
# 3            0.569316           0.635600           0.677396
# 4            0.641135           0.752955           0.694827
# 5            0.564347           0.719369           0.701568
# 6            0.675112           0.708810           0.718407
# 7            0.499574           0.472016           0.526468
# 8            0.612791           0.699076           0.717320
# 9            0.629735           0.682159           0.655443
# 10           0.590787           0.706464           0.703080
# 11           0.526773           0.724191           0.696938
# 12           0.640542           0.736450           0.686275
# 13           0.555332           0.714797           0.677454
# 14           0.523097           0.723426           0.704636
# 15           0.404317           0.552991           0.634290
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.692530         0.699001        0.041048                4
# 1            0.549304         0.635977        0.065114               13
# 2            0.750990         0.683700        0.055030                5
# 3            0.552204         0.608864        0.045137               14
# 4            0.602787         0.680962        0.053115                6
# 5            0.670757         0.663115        0.053795                9
# 6            0.706605         0.702873        0.014613                2
# 7            0.614755         0.562267        0.083279               16
# 8            0.729835         0.701226        0.046921                3
# 9            0.655304         0.661863        0.020707               11
# 10           0.687185         0.672053        0.042380                7
# 11           0.648051         0.670366        0.080040                8
# 12           0.705931         0.702981        0.037768                1
# 13           0.694508         0.646673        0.062111               12
# 14           0.723395         0.662409        0.076491               10
# 15           0.648547         0.587133        0.102303               15

# %%
age_input=float(input("Age"))
bmi_input=float(input("BMI"))
Children_input=float(input("Children"))
sex_male_input=int(input("Sex Male 0 or 1"))
smoker_yes_input=int(input("Smoker Yes 0 or 1"))
# Out:
# Age 26
# BMI 12
# Children 1
# Sex Male 0 or 1 0
# Smoker Yes 0 or 1 0

# %%
Future_Prediction=grid.predict([[age_input, bmi_input,Children_input,sex_male_input,smoker_yes_input]])
# Out:
# C:\Users\Thenm\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %%
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[3378.91]
