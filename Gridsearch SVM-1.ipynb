# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
indep=dataset[['age','bmi','children','sex_male','smoker_yes']]
dep=dataset['charges']

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid={'kernel':['rbf'],'C':[1000,2000,3000],'gamma':['auto','scale']}

# %%
grid = GridSearchCV(SVR(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(indep,dep)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [1000, 2000, 3000], 'gamma': ['auto', 'scale'],
#                          'kernel': ['rbf']},
#              verbose=3)

# %%
re=grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'C': 3000, 'gamma': 'auto', 'kernel': 'rbf'}:

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0       0.133350      0.007417         0.037846        0.001816     1000
# 1       0.107794      0.005733         0.046053        0.003536     1000
# 2       0.184837      0.005957         0.040699        0.003436     2000
# 3       0.106902      0.011645         0.051716        0.009812     2000
# 4       0.203619      0.012656         0.037276        0.000955     3000
# 5       0.095435      0.001642         0.033892        0.010009     3000
#
#   param_gamma param_kernel                                          params  \
# 0        auto          rbf   {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}
# 1       scale          rbf  {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}
# 2        auto          rbf   {'C': 2000, 'gamma': 'auto', 'kernel': 'rbf'}
# 3       scale          rbf  {'C': 2000, 'gamma': 'scale', 'kernel': 'rbf'}
# 4        auto          rbf   {'C': 3000, 'gamma': 'auto', 'kernel': 'rbf'}
# 5       scale          rbf  {'C': 3000, 'gamma': 'scale', 'kernel': 'rbf'}
#
#    split0_test_score  split1_test_score  split2_test_score  split3_test_score  \
# 0          -0.080692          -0.054347          -0.062876          -0.079329
# 1          -0.155430          -0.098267          -0.123724          -0.137137
# 2          -0.033126          -0.002835          -0.026545          -0.029140
# 3          -0.143510          -0.087595          -0.113312          -0.128591
# 4           0.011741           0.043659           0.013383           0.021694
# 5          -0.128958          -0.075578          -0.100199          -0.116051
#
#    split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0          -0.117983        -0.079045        0.021865                3
# 1          -0.206405        -0.144193        0.036262                6
# 2          -0.067392        -0.031808        0.020699                2
# 3          -0.193992        -0.133400        0.035492                5
# 4          -0.012948         0.015506        0.018217                1
# 5          -0.179304        -0.120018        0.034578                4
